# %%
from clifford.tools.g3c import random_line, random_circle
from pyganja import *

# %%
nb_draw_objects([random_line().value for i in range(10)])

# %%
nb_draw_objects([random_circle().value for i in range(10)])
